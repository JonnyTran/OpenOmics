# %%
from dask_kubernetes import KubeCluster

cluster = KubeCluster.from_yaml('worker-spec.yml')
cluster.scale_up(5)  # specify number of nodes explicitly

cluster.adapt(minimum=1, maximum=100)  # or dynamically scale based on current workload
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-ddd917b07321> in <module>
#       1 from dask_kubernetes import KubeCluster
#       2
# ----> 3 cluster = KubeCluster.from_yaml('worker-spec.yml')
#       4 cluster.scale_up(5)  # specify number of nodes explicitly
#       5
#
# /opt/anaconda3/lib/python3.6/site-packages/dask_kubernetes/core.py in from_yaml(cls, yaml_path, **kwargs)
#     309             d = yaml.safe_load(f)
#     310             d = dask.config.expand_environment_variables(d)
# --> 311             return cls.from_dict(d, **kwargs)
#     312
#     313     @property
#
# /opt/anaconda3/lib/python3.6/site-packages/dask_kubernetes/core.py in from_dict(cls, pod_spec, **kwargs)
#     271         KubeCluster.from_yaml
#     272         """
# --> 273         return cls(make_pod_from_dict(pod_spec), **kwargs)
#     274
#     275     @classmethod
#
# /opt/anaconda3/lib/python3.6/site-packages/dask_kubernetes/core.py in __init__(self, pod_template, name, namespace, n_workers, host, port, env, auth, **kwargs)
#     193
#     194         pod_template = clean_pod_template(pod_template)
# --> 195         ClusterAuth.load_first(auth)
#     196
#     197         self.core_api = kubernetes.client.CoreV1Api()
#
# /opt/anaconda3/lib/python3.6/site-packages/dask_kubernetes/auth.py in load_first(auth)
#      68         for auth_instance in auth:
#      69             try:
# ---> 70                 auth_instance.load()
#      71             except kubernetes.config.ConfigException as exc:
#      72                 logger.debug(
#
# /opt/anaconda3/lib/python3.6/site-packages/dask_kubernetes/auth.py in load(self)
#     119     def load(self):
#     120         kubernetes.config.load_kube_config(
# --> 121             self.config_file, self.context, None, self.persist_config
#     122         )
#     123
#
# /opt/anaconda3/lib/python3.6/site-packages/kubernetes/config/kube_config.py in load_kube_config(config_file, context, client_configuration, persist_config)
#     643     loader = _get_kube_config_loader_for_yaml_file(
#     644         config_file, active_context=context,
# --> 645         persist_config=persist_config)
#     646
#     647     if client_configuration is None:
#
# /opt/anaconda3/lib/python3.6/site-packages/kubernetes/config/kube_config.py in _get_kube_config_loader_for_yaml_file(filename, persist_config, **kwargs)
#     611         config_dict=kcfg.config,
#     612         config_base_path=None,
# --> 613         **kwargs)
#     614
#     615
#
# /opt/anaconda3/lib/python3.6/site-packages/kubernetes/config/kube_config.py in __init__(self, config_dict, active_context, get_google_credentials, config_base_path, config_persister)
#     151         self._user = None
#     152         self._cluster = None
# --> 153         self.set_active_context(active_context)
#     154         self._config_base_path = config_base_path
#     155         self._config_persister = config_persister
#
# /opt/anaconda3/lib/python3.6/site-packages/kubernetes/config/kube_config.py in set_active_context(self, context_name)
#     171     def set_active_context(self, context_name=None):
#     172         if context_name is None:
# --> 173             context_name = self._config['current-context']
#     174         self._current_context = self._config['contexts'].get_with_name(
#     175             context_name)
#
# /opt/anaconda3/lib/python3.6/site-packages/kubernetes/config/kube_config.py in __getitem__(self, key)
#     493
#     494     def __getitem__(self, key):
# --> 495         v = self.safe_get(key)
#     496         if not v:
#     497             raise ConfigException(
#
# /opt/anaconda3/lib/python3.6/site-packages/kubernetes/config/kube_config.py in safe_get(self, key)
#     489     def safe_get(self, key):
#     490         if (isinstance(self.value, list) and isinstance(key, int) or
# --> 491                 key in self.value):
#     492             return self.value[key]
#     493
#
# TypeError: argument of type 'NoneType' is not iterable
