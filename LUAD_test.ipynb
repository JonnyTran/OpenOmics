# %%
# Necessary imports
# %load_ext autoreload
# %autoreload 1

import networkx as nx
import numpy as np
import pandas as pd
import scipy.sparse as sps
import pickle

import dask.dataframe as dd

from openTCGA.multiomics import MultiOmicsData
from openTCGA.annotation import *

import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 10000)

# %%
folder_path = "/data/datasets/Bioinformatics_ExternalData/tcga-assembler/LUAD/"
external_data_path = "/data/datasets/Bioinformatics_ExternalData/"
luad_data = MultiOmicsData("LUAD", folder_path, external_data_path=external_data_path,
                           import_sequences="shortest", replace_U2T=True,
                           modalities=[\
                                       "GE",
                                       "MIR",
                                       "LNC",
                                       # "CNV",
                                       # "SNP",
#                                        "PRO",
                                       # "DNA"
                                       ])
# Out:
# Unmatched lncRNAs 12727
# Unmatched lncRNAs after ensembl: 879
# Unmatched lncRNAs after lncBase: 716
# Unmatched lncRNAs after HGNC: 674
# Unmatched lncRNAs after lncipedia: 555
# PATIENTS (522, 110)
# BIOSPECIMENS (126, 2)
# DRUGS (461, 4)
# GE (576, 20143)
# MIR (494, 1870)
# LNC (546, 12727)
# SAMPLES (599, 111)
# Processed genes info for  GE
# Processed genes info for  MIR
# Processed genes info for  LNC

# %%
gencode = GENCODE(import_folder="/data/datasets/Bioinformatics_ExternalData/GENCODE/")

# %%
ensemble_snp = EnsembleSNP()
ensemble_snp.filename
# Out:
# Querying hsapiens_gene_ensembl from www.ensembl.org...

# %%
ensemble_snp.df.head()

# %%
ensemble_somatic = EnsembleSomaticVariation()
ensemble_somatic.filename

# %%
ensemble_geneseq = EnsembleGeneSequences()

# %%
ensemble_transcriptseq = EnsembleTranscriptSequences()

# %%
from bioservices import BioMart

# %%
bm = BioMart(host="www.ensembl.org")

# %%
temp = pd.DataFrame()
for k,v in bm.attributes("hsapiens_gene_ensembl").items():
    temp[k] = v
temp.T
# Out:
#                                                                                                     0  \
# ensembl_gene_id                                                                        Gene stable ID
# ensembl_gene_id_version                                                        Gene stable ID version
# ensembl_transcript_id                                                            Transcript stable ID
# ensembl_transcript_id_version                                            Transcript stable ID version
# ensembl_peptide_id                                                                  Protein stable ID
# ensembl_peptide_id_version                                                  Protein stable ID version
# ensembl_exon_id                                                                        Exon stable ID
# description                                                                          Gene description
# chromosome_name                                                              Chromosome/scaffold name
# start_position                                                                        Gene start (bp)
# end_position                                                                            Gene end (bp)
# strand                                                                                         Strand
# band                                                                                   Karyotype band
# transcript_start                                                                Transcript start (bp)
# transcript_end                                                                    Transcript end (bp)
# transcription_start_site                                               Transcription start site (TSS)
# transcript_length                                          Transcript length (including UTRs and CDS)
# transcript_tsl                                                         Transcript support level (TSL)
# transcript_gencode_basic                                                     GENCODE basic annotation
# transcript_appris                                                                   APPRIS annotation
# transcript_mane_select                                                        RefSeq match transcript
# external_gene_name                                                                          Gene name
# external_gene_source                                                              Source of gene name
# external_transcript_name                                                              Transcript name
# external_transcript_source_name                                             Source of transcript name
# transcript_count                                                                     Transcript count
# percentage_gene_gc_content                                                          Gene % GC content
# gene_biotype                                                                                Gene type
# transcript_biotype                                                                    Transcript type
# source                                                                                  Source (gene)
# transcript_source                                                                 Source (transcript)
# version                                                                                Version (gene)
# transcript_version                                                               Version (transcript)
# peptide_version                                                                     Version (protein)
# phenotype_description                                                           Phenotype description
# source_name                                                                               Source name
# study_external_id                                                            Study external reference
# strain_name                                                                               Strain name
# strain_gender                                                                           Strain gender
# p_value                                                                                       P value
# go_id                                                                               GO term accession
# name_1006                                                                                GO term name
# definition_1006                                                                    GO term definition
# go_linkage_type                                                                 GO term evidence code
# namespace_1003                                                                              GO domain
# goslim_goa_accession                                                          GOSlim GOA Accession(s)
# goslim_goa_description                                                         GOSlim GOA Description
# ccds                                                                                          CCDS ID
# chembl                                                                                      ChEMBL ID
# clone_based_ensembl_gene                                                Clone-based (Ensembl) gene ID
# clone_based_ensembl_transcript                                    Clone-based (Ensembl) transcript ID
# dbass3_name                                                 DataBase of Aberrant 3' Splice Sites name
# dbass3_id                                                     DataBase of Aberrant 3' Splice Sites ID
# dbass5_name                                                 DataBase of Aberrant 5' Splice Sites name
# dbass5_id                                                     DataBase of Aberrant 5' Splice Sites ID
# ens_hs_transcript                                                         Ensembl Human Transcript ID
# ens_hs_translation                                                       Ensembl Human Translation ID
# entrezgene_trans_name                                                   EntrezGene transcript name ID
# embl                                                                   European Nucleotide Archive ID
# arrayexpress                                                                      Expression Atlas ID
# genedb                                                                                      GeneDB ID
# hgnc_id                                                                                       HGNC ID
# hgnc_symbol                                                                               HGNC symbol
# hgnc_trans_name                                                               HGNC transcript name ID
# hpa_accession                                                           Human Protein Atlas accession
# hpa_id                                                                         Human Protein Atlas ID
# protein_id                                                                           INSDC protein ID
# kegg_enzyme                                                                KEGG Pathway and Enzyme ID
# ens_lrg_gene                                                           LRG display in Ensembl gene ID
# ens_lrg_transcript                                               LRG display in Ensembl transcript ID
# merops                                                             MEROPS - the Peptidase Database ID
# mim_gene_description                                                             MIM gene description
# mim_gene_accession                                                                 MIM gene accession
# mim_morbid_description                                                         MIM morbid description
# mim_morbid_accession                                                             MIM morbid accession
# mirbase_accession                                                                   miRBase accession
# mirbase_id                                                                                 miRBase ID
# mirbase_trans_name                                                         miRBase transcript name ID
# entrezgene_description                                                          NCBI gene description
# entrezgene_accession                                                              NCBI gene accession
# entrezgene_id                                                                            NCBI gene ID
# pdb                                                                                            PDB ID
# reactome                                                                                  Reactome ID
# reactome_gene                                                                        Reactome gene ID
# reactome_transcript                                                            Reactome transcript ID
# refseq_mrna                                                                            RefSeq mRNA ID
# refseq_mrna_predicted                                                        RefSeq mRNA predicted ID
# refseq_ncrna                                                                          RefSeq ncRNA ID
# refseq_ncrna_predicted                                                      RefSeq ncRNA predicted ID
# refseq_peptide                                                                      RefSeq peptide ID
# refseq_peptide_predicted                                                  RefSeq peptide predicted ID
# rfam                                                                                          RFAM ID
# rfam_trans_name                                                               RFAM transcript name ID
# rnacentral                                                                              RNAcentral ID
# ucsc                                                                                   UCSC Stable ID
# uniparc                                                                                    UniParc ID
# uniprot_gn_symbol                                                          UniProtKB Gene Name symbol
# uniprot_gn_id                                                                  UniProtKB Gene Name ID
# uniprotswissprot                                                              UniProtKB/Swiss-Prot ID
# uniprotsptrembl                                                                   UniProtKB/TrEMBL ID
# wikigene_description                                                             WikiGene description
# wikigene_name                                                                           WikiGene name
# wikigene_id                                                                               WikiGene ID
# affy_hc_g110                                                                       AFFY HC G110 probe
# affy_hg_focus                                                                     AFFY HG Focus probe
# affy_hg_u133a                                                                     AFFY HG U133A probe
# affy_hg_u133a_2                                                                 AFFY HG U133A 2 probe
# affy_hg_u133b                                                                     AFFY HG U133B probe
# affy_hg_u133_plus_2                                                         AFFY HG U133 Plus 2 probe
# affy_hg_u95a                                                                       AFFY HG U95A probe
# affy_hg_u95av2                                                                   AFFY HG U95Av2 probe
# affy_hg_u95b                                                                       AFFY HG U95B probe
# affy_hg_u95c                                                                       AFFY HG U95C probe
# affy_hg_u95d                                                                       AFFY HG U95D probe
# affy_hg_u95e                                                                       AFFY HG U95E probe
# affy_hta_2_0                                                                       AFFY HTA 2 0 probe
# affy_huex_1_0_st_v2                                                         AFFY HuEx 1 0 st v2 probe
# affy_hugenefl                                                                     AFFY HuGeneFL probe
# affy_hugene_1_0_st_v1                                                     AFFY HuGene 1 0 st v1 probe
# affy_hugene_2_0_st_v1                                                     AFFY HuGene 2 0 st v1 probe
# affy_primeview                                                                   AFFY PrimeView probe
# affy_u133_x3p                                                                     AFFY U133 X3P probe
# agilent_cgh_44b                                                                 AGILENT CGH 44b probe
# agilent_gpl6848                                                                 AGILENT GPL6848 probe
# agilent_sureprint_g3_ge_8x60k                                     AGILENT SurePrint G3 GE 8x60k probe
# agilent_sureprint_g3_ge_8x60k_v2                               AGILENT SurePrint G3 GE 8x60k v2 probe
# agilent_wholegenome                                                         AGILENT WholeGenome probe
# agilent_wholegenome_4x44k_v1                                       AGILENT WholeGenome 4x44k v1 probe
# agilent_wholegenome_4x44k_v2                                       AGILENT WholeGenome 4x44k v2 probe
# codelink_codelink                                                             CODELINK CODELINK probe
# illumina_humanht_12_v3                                                   ILLUMINA HumanHT 12 V3 probe
# illumina_humanht_12_v4                                                   ILLUMINA HumanHT 12 V4 probe
# illumina_humanref_8_v3                                                   ILLUMINA HumanRef 8 V3 probe
# illumina_humanwg_6_v1                                                     ILLUMINA HumanWG 6 V1 probe
# illumina_humanwg_6_v2                                                     ILLUMINA HumanWG 6 V2 probe
# illumina_humanwg_6_v3                                                     ILLUMINA HumanWG 6 V3 probe
# phalanx_onearray                                                               PHALANX OneArray probe
# family                                                                   Ensembl Protein Family ID(s)
# family_description                                                         Ensembl Family Description
# cdd                                                                                            CDD ID
# cdd_start                                                                                   CDD start
# cdd_end                                                                                       CDD end
# gene3d                                                                                      Gene3D ID
# gene3d_start                                                                             Gene3D start
# gene3d_end                                                                                 Gene3D end
# hamap                                                                                        HAMAP ID
# hamap_start                                                                               HAMAP start
# hamap_end                                                                                   HAMAP end
# hmmpanther                                                                                 PANTHER ID
# hmmpanther_start                                                                        PANTHER start
# hmmpanther_end                                                                            PANTHER end
# pfam                                                                                          Pfam ID
# pfam_start                                                                                 Pfam start
# pfam_end                                                                                     Pfam end
# pirsf                                                                                        PIRSF ID
# pirsf_start                                                                               PIRSF start
# pirsf_end                                                                                   PIRSF end
# prints                                                                                      Prints ID
# prints_start                                                                             Prints start
# prints_end                                                                                 Prints end
# blastprodom                                                                                 ProDom ID
# blastprodom_start                                                                        ProDom start
# blastprodom_end                                                                            ProDom end
# scanprosite                                                                       PROSITE patterns ID
# scanprosite_start                                                              PROSITE patterns start
# scanprosite_end                                                                  PROSITE patterns end
# pfscan                                                                            PROSITE profiles ID
# pfscan_start                                                                   PROSITE profiles start
# pfscan_end                                                                       PROSITE profiles end
# sfld                                                                                          SFLD ID
# sfld_start                                                                                 SFLD start
# sfld_end                                                                                     SFLD end
# smart                                                                                        SMART ID
# smart_start                                                                               SMART start
# smart_end                                                                                   SMART end
# superfamily                                                                            Superfamily ID
# superfamily_start                                                                   Superfamily start
# superfamily_end                                                                       Superfamily end
# tigrfam                                                                                    TIGRFAM ID
# tigrfam_start                                                                           TIGRFAM start
# tigrfam_end                                                                               TIGRFAM end
# interpro                                                                                  Interpro ID
# interpro_short_description                                                 Interpro Short Description
# interpro_description                                                             Interpro Description
# interpro_start                                                                         Interpro start
# interpro_end                                                                             Interpro end
# mobidblite                                                                                MobiDB lite
# mobidblite_start                                                                    MobiDB lite start
# mobidblite_end                                                                        MobiDB lite end
# ncoils                                                                          Coiled-coils (Ncoils)
# ncoils_start                                                              Coiled-coils (Ncoils) start
# ncoils_end                                                                  Coiled-coils (Ncoils) end
# seg                                                                              Low complexity (Seg)
# seg_start                                                                  Low complexity (Seg) start
# seg_end                                                                      Low complexity (Seg) end
# sifts_import                                                                        PDB-ENSP mappings
# sifts_import_start                                                            PDB-ENSP mappings start
# sifts_import_end                                                                PDB-ENSP mappings end
# signalp                                                                       Cleavage site (Signalp)
# signalp_start                                                           Cleavage site (Signalp) start
# signalp_end                                                               Cleavage site (Signalp) end
# tmhmm                                                                           Transmembrane helices
# tmhmm_start                                                               Transmembrane helices start
# tmhmm_end                                                                   Transmembrane helices end
# 5_utr_start                                                                              5' UTR start
# 5_utr_end                                                                                  5' UTR end
# 3_utr_start                                                                              3' UTR start
# 3_utr_end                                                                                  3' UTR end
# cds_length                                                                                 CDS Length
# exon_chrom_start                                                               Exon region start (bp)
# exon_chrom_end                                                                   Exon region end (bp)
# is_constitutive                                                                     Constitutive exon
# rank                                                                          Exon rank in transcript
# phase                                                                                     Start phase
# end_phase                                                                                   End phase
# cdna_coding_start                                                                   cDNA coding start
# cdna_coding_end                                                                       cDNA coding end
# genomic_coding_start                                                             Genomic coding start
# genomic_coding_end                                                                 Genomic coding end
# cds_start                                                                                   CDS start
# cds_end                                                                                       CDS end
# cabingdonii_homolog_ensembl_gene                        Abingdon island giant tortoise gene stable ID
# cabingdonii_homolog_associated_gene_name                     Abingdon island giant tortoise gene name
# cabingdonii_homolog_ensembl_peptide                 Abingdon island giant tortoise protein or tran...
# cabingdonii_homolog_chromosome                      Abingdon island giant tortoise chromosome/scaf...
# cabingdonii_homolog_chrom_start                     Abingdon island giant tortoise chromosome/scaf...
# cabingdonii_homolog_chrom_end                       Abingdon island giant tortoise chromosome/scaf...
# cabingdonii_homolog_canonical_transcript_protein                       Query protein or transcript ID
# cabingdonii_homolog_subtype                         Last common ancestor with Abingdon island gian...
# cabingdonii_homolog_orthology_type                       Abingdon island giant tortoise homology type
# cabingdonii_homolog_perc_id                         %id. target Abingdon island giant tortoise gen...
# cabingdonii_homolog_perc_id_r1                      %id. query gene identical to target Abingdon i...
# cabingdonii_homolog_goc_score                       Abingdon island giant tortoise Gene-order cons...
# cabingdonii_homolog_wga_coverage                    Abingdon island giant tortoise Whole-genome al...
# cabingdonii_homolog_dn                                         dN with Abingdon island giant tortoise
# cabingdonii_homolog_ds                                         dS with Abingdon island giant tortoise
# cabingdonii_homolog_orthology_confidence            Abingdon island giant tortoise orthology confi...
# gagassizii_homolog_ensembl_gene                              Agassiz's desert tortoise gene stable ID
# gagassizii_homolog_associated_gene_name                           Agassiz's desert tortoise gene name
# gagassizii_homolog_ensembl_peptide                  Agassiz's desert tortoise protein or transcrip...
# gagassizii_homolog_chromosome                       Agassiz's desert tortoise chromosome/scaffold ...
# gagassizii_homolog_chrom_start                      Agassiz's desert tortoise chromosome/scaffold ...
# gagassizii_homolog_chrom_end                        Agassiz's desert tortoise chromosome/scaffold ...
# gagassizii_homolog_canonical_transcript_protein                        Query protein or transcript ID
# gagassizii_homolog_subtype                          Last common ancestor with Agassiz's desert tor...
# gagassizii_homolog_orthology_type                             Agassiz's desert tortoise homology type
# gagassizii_homolog_perc_id                          %id. target Agassiz's desert tortoise gene ide...
# gagassizii_homolog_perc_id_r1                       %id. query gene identical to target Agassiz's ...
# gagassizii_homolog_goc_score                        Agassiz's desert tortoise Gene-order conservat...
# gagassizii_homolog_wga_coverage                     Agassiz's desert tortoise Whole-genome alignme...
# gagassizii_homolog_dn                                               dN with Agassiz's desert tortoise
# gagassizii_homolog_ds                                               dS with Agassiz's desert tortoise
# gagassizii_homolog_orthology_confidence             Agassiz's desert tortoise orthology confidence...
# mspretus_homolog_ensembl_gene                                           Algerian mouse gene stable ID
# mspretus_homolog_associated_gene_name                                        Algerian mouse gene name
# mspretus_homolog_ensembl_peptide                       Algerian mouse protein or transcript stable ID
# mspretus_homolog_chromosome                                   Algerian mouse chromosome/scaffold name
# mspretus_homolog_chrom_start                            Algerian mouse chromosome/scaffold start (bp)
# mspretus_homolog_chrom_end                                Algerian mouse chromosome/scaffold end (bp)
# mspretus_homolog_canonical_transcript_protein                          Query protein or transcript ID
# mspretus_homolog_subtype                                     Last common ancestor with Algerian mouse
# mspretus_homolog_orthology_type                                          Algerian mouse homology type
# mspretus_homolog_perc_id                            %id. target Algerian mouse gene identical to q...
# mspretus_homolog_perc_id_r1                         %id. query gene identical to target Algerian m...
# mspretus_homolog_goc_score                               Algerian mouse Gene-order conservation score
# mspretus_homolog_wga_coverage                          Algerian mouse Whole-genome alignment coverage
# mspretus_homolog_dn                                                            dN with Algerian mouse
# mspretus_homolog_ds                                                            dS with Algerian mouse
# mspretus_homolog_orthology_confidence               Algerian mouse orthology confidence [0 low, 1 ...
# vpacos_homolog_ensembl_gene                                                     Alpaca gene stable ID
# vpacos_homolog_associated_gene_name                                                  Alpaca gene name
# vpacos_homolog_ensembl_peptide                                 Alpaca protein or transcript stable ID
# vpacos_homolog_chromosome                                             Alpaca chromosome/scaffold name
# vpacos_homolog_chrom_start                                      Alpaca chromosome/scaffold start (bp)
# vpacos_homolog_chrom_end                                          Alpaca chromosome/scaffold end (bp)
# vpacos_homolog_canonical_transcript_protein                            Query protein or transcript ID
# vpacos_homolog_subtype                                               Last common ancestor with Alpaca
# vpacos_homolog_orthology_type                                                    Alpaca homology type
# vpacos_homolog_perc_id                                %id. target Alpaca gene identical to query gene
# vpacos_homolog_perc_id_r1                             %id. query gene identical to target Alpaca gene
# vpacos_homolog_goc_score                                         Alpaca Gene-order conservation score
# vpacos_homolog_wga_coverage                                    Alpaca Whole-genome alignment coverage
# vpacos_homolog_dn                                                                      dN with Alpaca
# vpacos_homolog_ds                                                                      dS with Alpaca
# vpacos_homolog_orthology_confidence                       Alpaca orthology confidence [0 low, 1 high]
# mmarmota_homolog_ensembl_gene                                            Alpine marmot gene stable ID
# mmarmota_homolog_associated_gene_name                                         Alpine marmot gene name
# mmarmota_homolog_ensembl_peptide                        Alpine marmot protein or transcript stable ID
# mmarmota_homolog_chromosome                                    Alpine marmot chromosome/scaffold name
# mmarmota_homolog_chrom_start                             Alpine marmot chromosome/scaffold start (bp)
# mmarmota_homolog_chrom_end                                 Alpine marmot chromosome/scaffold end (bp)
# mmarmota_homolog_canonical_transcript_protein                          Query protein or transcript ID
# mmarmota_homolog_subtype                                      Last common ancestor with Alpine marmot
# mmarmota_homolog_orthology_type                                           Alpine marmot homology type
# mmarmota_homolog_perc_id                            %id. target Alpine marmot gene identical to qu...
# mmarmota_homolog_perc_id_r1                         %id. query gene identical to target Alpine mar...
# mmarmota_homolog_goc_score                                Alpine marmot Gene-order conservation score
# mmarmota_homolog_wga_coverage                           Alpine marmot Whole-genome alignment coverage
# mmarmota_homolog_dn                                                             dN with Alpine marmot
# mmarmota_homolog_ds                                                             dS with Alpine marmot
# mmarmota_homolog_orthology_confidence               Alpine marmot orthology confidence [0 low, 1 h...
# pformosa_homolog_ensembl_gene                                             Amazon molly gene stable ID
# pformosa_homolog_associated_gene_name                                          Amazon molly gene name
# pformosa_homolog_ensembl_peptide                         Amazon molly protein or transcript stable ID
# pformosa_homolog_chromosome                                     Amazon molly chromosome/scaffold name
# pformosa_homolog_chrom_start                              Amazon molly chromosome/scaffold start (bp)
# pformosa_homolog_chrom_end                                  Amazon molly chromosome/scaffold end (bp)
# pformosa_homolog_canonical_transcript_protein                          Query protein or transcript ID
# pformosa_homolog_subtype                                       Last common ancestor with Amazon molly
# pformosa_homolog_orthology_type                                            Amazon molly homology type
# pformosa_homolog_perc_id                            %id. target Amazon molly gene identical to que...
# pformosa_homolog_perc_id_r1                         %id. query gene identical to target Amazon mol...
# pformosa_homolog_goc_score                                 Amazon molly Gene-order conservation score
# pformosa_homolog_wga_coverage                            Amazon molly Whole-genome alignment coverage
# pformosa_homolog_dn                                                              dN with Amazon molly
# pformosa_homolog_ds                                                              dS with Amazon molly
# pformosa_homolog_orthology_confidence               Amazon molly orthology confidence [0 low, 1 high]
# ccanadensis_homolog_ensembl_gene                                       American beaver gene stable ID
# ccanadensis_homolog_associated_gene_name                                    American beaver gene name
# ccanadensis_homolog_ensembl_peptide                   American beaver protein or transcript stable ID
# ccanadensis_homolog_chromosome                               American beaver chromosome/scaffold name
# ccanadensis_homolog_chrom_start                        American beaver chromosome/scaffold start (bp)
# ccanadensis_homolog_chrom_end                            American beaver chromosome/scaffold end (bp)
# ccanadensis_homolog_canonical_transcript_protein                       Query protein or transcript ID
# ccanadensis_homolog_subtype                                 Last common ancestor with American beaver
# ccanadensis_homolog_orthology_type                                      American beaver homology type
# ccanadensis_homolog_perc_id                         %id. target American beaver gene identical to ...
# ccanadensis_homolog_perc_id_r1                      %id. query gene identical to target American b...
# ccanadensis_homolog_goc_score                           American beaver Gene-order conservation score
# ccanadensis_homolog_wga_coverage                      American beaver Whole-genome alignment coverage
# ccanadensis_homolog_dn                                                        dN with American beaver
# ccanadensis_homolog_ds                                                        dS with American beaver
# ccanadensis_homolog_orthology_confidence            American beaver orthology confidence [0 low, 1...
# bbison_homolog_ensembl_gene                                             American bison gene stable ID
# bbison_homolog_associated_gene_name                                          American bison gene name
# bbison_homolog_ensembl_peptide                         American bison protein or transcript stable ID
# bbison_homolog_chromosome                                     American bison chromosome/scaffold name
# bbison_homolog_chrom_start                              American bison chromosome/scaffold start (bp)
# bbison_homolog_chrom_end                                  American bison chromosome/scaffold end (bp)
# bbison_homolog_canonical_transcript_protein                            Query protein or transcript ID
# bbison_homolog_subtype                                       Last common ancestor with American bison
# bbison_homolog_orthology_type                                            American bison homology type
# bbison_homolog_perc_id                              %id. target American bison gene identical to q...
# bbison_homolog_perc_id_r1                           %id. query gene identical to target American b...
# bbison_homolog_goc_score                                 American bison Gene-order conservation score
# bbison_homolog_wga_coverage                            American bison Whole-genome alignment coverage
# bbison_homolog_dn                                                              dN with American bison
# bbison_homolog_ds                                                              dS with American bison
# bbison_homolog_orthology_confidence                 American bison orthology confidence [0 low, 1 ...
# uamericanus_homolog_ensembl_gene                                   American black bear gene stable ID
# uamericanus_homolog_associated_gene_name                                American black bear gene name
# uamericanus_homolog_ensembl_peptide                 American black bear protein or transcript stab...
# uamericanus_homolog_chromosome                           American black bear chromosome/scaffold name
# uamericanus_homolog_chrom_start                     American black bear chromosome/scaffold start ...
# uamericanus_homolog_chrom_end                        American black bear chromosome/scaffold end (bp)
# uamericanus_homolog_canonical_transcript_protein                       Query protein or transcript ID
# uamericanus_homolog_subtype                             Last common ancestor with American black bear
# uamericanus_homolog_orthology_type                                  American black bear homology type
# uamericanus_homolog_perc_id                         %id. target American black bear gene identical...
# uamericanus_homolog_perc_id_r1                      %id. query gene identical to target American b...
# uamericanus_homolog_goc_score                       American black bear Gene-order conservation score
# uamericanus_homolog_wga_coverage                    American black bear Whole-genome alignment cov...
# uamericanus_homolog_dn                                                    dN with American black bear
# uamericanus_homolog_ds                                                    dS with American black bear
# uamericanus_homolog_orthology_confidence            American black bear orthology confidence [0 lo...
# nvison_homolog_ensembl_gene                                              American mink gene stable ID
# nvison_homolog_associated_gene_name                                           American mink gene name
# nvison_homolog_ensembl_peptide                          American mink protein or transcript stable ID
# nvison_homolog_chromosome                                      American mink chromosome/scaffold name
# nvison_homolog_chrom_start                               American mink chromosome/scaffold start (bp)
# nvison_homolog_chrom_end                                   American mink chromosome/scaffold end (bp)
# nvison_homolog_canonical_transcript_protein                            Query protein or transcript ID
# nvison_homolog_subtype                                        Last common ancestor with American mink
# nvison_homolog_orthology_type                                             American mink homology type
# nvison_homolog_perc_id                              %id. target American mink gene identical to qu...
# nvison_homolog_perc_id_r1                           %id. query gene identical to target American m...
# nvison_homolog_goc_score                                  American mink Gene-order conservation score
# nvison_homolog_wga_coverage                             American mink Whole-genome alignment coverage
# nvison_homolog_dn                                                               dN with American mink
# nvison_homolog_ds                                                               dS with American mink
# nvison_homolog_orthology_confidence                 American mink orthology confidence [0 low, 1 h...
# cpalliatus_homolog_ensembl_gene                                         Angola colobus gene stable ID
# cpalliatus_homolog_associated_gene_name                                      Angola colobus gene name
# cpalliatus_homolog_ensembl_peptide                     Angola colobus protein or transcript stable ID
# cpalliatus_homolog_chromosome                                 Angola colobus chromosome/scaffold name
# cpalliatus_homolog_chrom_start                          Angola colobus chromosome/scaffold start (bp)
# cpalliatus_homolog_chrom_end                              Angola colobus chromosome/scaffold end (bp)
# cpalliatus_homolog_canonical_transcript_protein                        Query protein or transcript ID
# cpalliatus_homolog_subtype                                   Last common ancestor with Angola colobus
# cpalliatus_homolog_orthology_type                                        Angola colobus homology type
# cpalliatus_homolog_perc_id                          %id. target Angola colobus gene identical to q...
# cpalliatus_homolog_perc_id_r1                       %id. query gene identical to target Angola col...
# cpalliatus_homolog_goc_score                             Angola colobus Gene-order conservation score
# cpalliatus_homolog_wga_coverage                        Angola colobus Whole-genome alignment coverage
# cpalliatus_homolog_dn                                                          dN with Angola colobus
# cpalliatus_homolog_ds                                                          dS with Angola colobus
# cpalliatus_homolog_orthology_confidence             Angola colobus orthology confidence [0 low, 1 ...
# acarolinensis_homolog_ensembl_gene                                        Anole lizard gene stable ID
# acarolinensis_homolog_associated_gene_name                                     Anole lizard gene name
# acarolinensis_homolog_ensembl_peptide                    Anole lizard protein or transcript stable ID
# acarolinensis_homolog_chromosome                                Anole lizard chromosome/scaffold name
# acarolinensis_homolog_chrom_start                         Anole lizard chromosome/scaffold start (bp)
# acarolinensis_homolog_chrom_end                             Anole lizard chromosome/scaffold end (bp)
# acarolinensis_homolog_canonical_transcript_protein                     Query protein or transcript ID
# acarolinensis_homolog_subtype                                  Last common ancestor with Anole lizard
# acarolinensis_homolog_orthology_type                                       Anole lizard homology type
# acarolinensis_homolog_perc_id                       %id. target Anole lizard gene identical to que...
# acarolinensis_homolog_perc_id_r1                    %id. query gene identical to target Anole liza...
# acarolinensis_homolog_goc_score                            Anole lizard Gene-order conservation score
# acarolinensis_homolog_wga_coverage                       Anole lizard Whole-genome alignment coverage
# acarolinensis_homolog_dn                                                         dN with Anole lizard
# acarolinensis_homolog_ds                                                         dS with Anole lizard
# acarolinensis_homolog_orthology_confidence          Anole lizard orthology confidence [0 low, 1 high]
# uparryii_homolog_ensembl_gene                                   Arctic ground squirrel gene stable ID
# uparryii_homolog_associated_gene_name                                Arctic ground squirrel gene name
# uparryii_homolog_ensembl_peptide                    Arctic ground squirrel protein or transcript s...
# uparryii_homolog_chromosome                           Arctic ground squirrel chromosome/scaffold name
# uparryii_homolog_chrom_start                        Arctic ground squirrel chromosome/scaffold sta...
# uparryii_homolog_chrom_end                          Arctic ground squirrel chromosome/scaffold end...
# uparryii_homolog_canonical_transcript_protein                          Query protein or transcript ID
# uparryii_homolog_subtype                             Last common ancestor with Arctic ground squirrel
# uparryii_homolog_orthology_type                                  Arctic ground squirrel homology type
# uparryii_homolog_perc_id                            %id. target Arctic ground squirrel gene identi...
# uparryii_homolog_perc_id_r1                         %id. query gene identical to target Arctic gro...
# uparryii_homolog_goc_score                          Arctic ground squirrel Gene-order conservation...
# uparryii_homolog_wga_coverage                       Arctic ground squirrel Whole-genome alignment ...
# uparryii_homolog_dn                                                    dN with Arctic ground squirrel
# uparryii_homolog_ds                                                    dS with Arctic ground squirrel
# uparryii_homolog_orthology_confidence               Arctic ground squirrel orthology confidence [0...
# smerianae_homolog_ensembl_gene                          Argentine black and white tegu gene stable ID
# smerianae_homolog_associated_gene_name                       Argentine black and white tegu gene name
# smerianae_homolog_ensembl_peptide                   Argentine black and white tegu protein or tran...
# smerianae_homolog_chromosome                        Argentine black and white tegu chromosome/scaf...
# smerianae_homolog_chrom_start                       Argentine black and white tegu chromosome/scaf...
# smerianae_homolog_chrom_end                         Argentine black and white tegu chromosome/scaf...
# smerianae_homolog_canonical_transcript_protein                         Query protein or transcript ID
# smerianae_homolog_subtype                           Last common ancestor with Argentine black and ...
# smerianae_homolog_orthology_type                         Argentine black and white tegu homology type
# smerianae_homolog_perc_id                           %id. target Argentine black and white tegu gen...
# smerianae_homolog_perc_id_r1                        %id. query gene identical to target Argentine ...
# smerianae_homolog_goc_score                         Argentine black and white tegu Gene-order cons...
# smerianae_homolog_wga_coverage                      Argentine black and white tegu Whole-genome al...
# smerianae_homolog_dn                                           dN with Argentine black and white tegu
# smerianae_homolog_ds                                           dS with Argentine black and white tegu
# smerianae_homolog_orthology_confidence              Argentine black and white tegu orthology confi...
# dnovemcinctus_homolog_ensembl_gene                                           Armadillo gene stable ID
# dnovemcinctus_homolog_associated_gene_name                                        Armadillo gene name
# dnovemcinctus_homolog_ensembl_peptide                       Armadillo protein or transcript stable ID
# dnovemcinctus_homolog_chromosome                                   Armadillo chromosome/scaffold name
# dnovemcinctus_homolog_chrom_start                            Armadillo chromosome/scaffold start (bp)
# dnovemcinctus_homolog_chrom_end                                Armadillo chromosome/scaffold end (bp)
# dnovemcinctus_homolog_canonical_transcript_protein                     Query protein or transcript ID
# dnovemcinctus_homolog_subtype                                     Last common ancestor with Armadillo
# dnovemcinctus_homolog_orthology_type                                          Armadillo homology type
# dnovemcinctus_homolog_perc_id                       %id. target Armadillo gene identical to query ...
# dnovemcinctus_homolog_perc_id_r1                    %id. query gene identical to target Armadillo ...
# ...
# bmutus_homolog_wga_coverage                                           wga_coverage_4014
# bmutus_homolog_dn                                                               dn_4014
# bmutus_homolog_ds                                                               ds_4014
# bmutus_homolog_orthology_confidence                             is_high_confidence_4014
# xtropicalis_homolog_ensembl_gene                                      stable_id_4016_r2
# xtropicalis_homolog_associated_gene_name                         display_label_40273_r1
# xtropicalis_homolog_ensembl_peptide                                   stable_id_4016_r3
# xtropicalis_homolog_chromosome                                         chr_name_4016_r2
# xtropicalis_homolog_chrom_start                                       chr_start_4016_r2
# xtropicalis_homolog_chrom_end                                           chr_end_4016_r2
# xtropicalis_homolog_canonical_transcript_protein                      stable_id_4016_r1
# xtropicalis_homolog_subtype                                             node_name_40192
# xtropicalis_homolog_orthology_type                                     description_4014
# xtropicalis_homolog_perc_id                                                perc_id_4015
# xtropicalis_homolog_perc_id_r1                                          perc_id_4015_r1
# xtropicalis_homolog_goc_score                                            goc_score_4014
# xtropicalis_homolog_wga_coverage                                      wga_coverage_4014
# xtropicalis_homolog_dn                                                          dn_4014
# xtropicalis_homolog_ds                                                          ds_4014
# xtropicalis_homolog_orthology_confidence                        is_high_confidence_4014
# sdorsalis_homolog_ensembl_gene                                        stable_id_4016_r2
# sdorsalis_homolog_associated_gene_name                           display_label_40273_r1
# sdorsalis_homolog_ensembl_peptide                                     stable_id_4016_r3
# sdorsalis_homolog_chromosome                                           chr_name_4016_r2
# sdorsalis_homolog_chrom_start                                         chr_start_4016_r2
# sdorsalis_homolog_chrom_end                                             chr_end_4016_r2
# sdorsalis_homolog_canonical_transcript_protein                        stable_id_4016_r1
# sdorsalis_homolog_subtype                                               node_name_40192
# sdorsalis_homolog_orthology_type                                       description_4014
# sdorsalis_homolog_perc_id                                                  perc_id_4015
# sdorsalis_homolog_perc_id_r1                                            perc_id_4015_r1
# sdorsalis_homolog_goc_score                                              goc_score_4014
# sdorsalis_homolog_wga_coverage                                        wga_coverage_4014
# sdorsalis_homolog_dn                                                            dn_4014
# sdorsalis_homolog_ds                                                            ds_4014
# sdorsalis_homolog_orthology_confidence                          is_high_confidence_4014
# tguttata_homolog_ensembl_gene                                         stable_id_4016_r2
# tguttata_homolog_associated_gene_name                            display_label_40273_r1
# tguttata_homolog_ensembl_peptide                                      stable_id_4016_r3
# tguttata_homolog_chromosome                                            chr_name_4016_r2
# tguttata_homolog_chrom_start                                          chr_start_4016_r2
# tguttata_homolog_chrom_end                                              chr_end_4016_r2
# tguttata_homolog_canonical_transcript_protein                         stable_id_4016_r1
# tguttata_homolog_subtype                                                node_name_40192
# tguttata_homolog_orthology_type                                        description_4014
# tguttata_homolog_perc_id                                                   perc_id_4015
# tguttata_homolog_perc_id_r1                                             perc_id_4015_r1
# tguttata_homolog_goc_score                                               goc_score_4014
# tguttata_homolog_wga_coverage                                         wga_coverage_4014
# tguttata_homolog_dn                                                             dn_4014
# tguttata_homolog_ds                                                             ds_4014
# tguttata_homolog_orthology_confidence                           is_high_confidence_4014
# mzebra_homolog_ensembl_gene                                           stable_id_4016_r2
# mzebra_homolog_associated_gene_name                              display_label_40273_r1
# mzebra_homolog_ensembl_peptide                                        stable_id_4016_r3
# mzebra_homolog_chromosome                                              chr_name_4016_r2
# mzebra_homolog_chrom_start                                            chr_start_4016_r2
# mzebra_homolog_chrom_end                                                chr_end_4016_r2
# mzebra_homolog_canonical_transcript_protein                           stable_id_4016_r1
# mzebra_homolog_subtype                                                  node_name_40192
# mzebra_homolog_orthology_type                                          description_4014
# mzebra_homolog_perc_id                                                     perc_id_4015
# mzebra_homolog_perc_id_r1                                               perc_id_4015_r1
# mzebra_homolog_goc_score                                                 goc_score_4014
# mzebra_homolog_wga_coverage                                           wga_coverage_4014
# mzebra_homolog_dn                                                               dn_4014
# mzebra_homolog_ds                                                               ds_4014
# mzebra_homolog_orthology_confidence                             is_high_confidence_4014
# drerio_homolog_ensembl_gene                                           stable_id_4016_r2
# drerio_homolog_associated_gene_name                              display_label_40273_r1
# drerio_homolog_ensembl_peptide                                        stable_id_4016_r3
# drerio_homolog_chromosome                                              chr_name_4016_r2
# drerio_homolog_chrom_start                                            chr_start_4016_r2
# drerio_homolog_chrom_end                                                chr_end_4016_r2
# drerio_homolog_canonical_transcript_protein                           stable_id_4016_r1
# drerio_homolog_subtype                                                  node_name_40192
# drerio_homolog_orthology_type                                          description_4014
# drerio_homolog_perc_id                                                     perc_id_4015
# drerio_homolog_perc_id_r1                                               perc_id_4015_r1
# drerio_homolog_goc_score                                                 goc_score_4014
# drerio_homolog_wga_coverage                                           wga_coverage_4014
# drerio_homolog_dn                                                               dn_4014
# drerio_homolog_ds                                                               ds_4014
# drerio_homolog_orthology_confidence                             is_high_confidence_4014
# marmatus_homolog_ensembl_gene                                         stable_id_4016_r2
# marmatus_homolog_associated_gene_name                            display_label_40273_r1
# marmatus_homolog_ensembl_peptide                                      stable_id_4016_r3
# marmatus_homolog_chromosome                                            chr_name_4016_r2
# marmatus_homolog_chrom_start                                          chr_start_4016_r2
# marmatus_homolog_chrom_end                                              chr_end_4016_r2
# marmatus_homolog_canonical_transcript_protein                         stable_id_4016_r1
# marmatus_homolog_subtype                                                node_name_40192
# marmatus_homolog_orthology_type                                        description_4014
# marmatus_homolog_perc_id                                                   perc_id_4015
# marmatus_homolog_perc_id_r1                                             perc_id_4015_r1
# marmatus_homolog_goc_score                                               goc_score_4014
# marmatus_homolog_wga_coverage                                         wga_coverage_4014
# marmatus_homolog_dn                                                             dn_4014
# marmatus_homolog_ds                                                             ds_4014
# marmatus_homolog_orthology_confidence                           is_high_confidence_4014
# hsapiens_paralog_ensembl_gene                                         stable_id_4016_r2
# hsapiens_paralog_associated_gene_name                            display_label_40273_r1
# hsapiens_paralog_ensembl_peptide                                      stable_id_4016_r3
# hsapiens_paralog_chromosome                                            chr_name_4016_r2
# hsapiens_paralog_chrom_start                                          chr_start_4016_r2
# hsapiens_paralog_chrom_end                                              chr_end_4016_r2
# hsapiens_paralog_canonical_transcript_protein                         stable_id_4016_r1
# hsapiens_paralog_subtype                                                node_name_40192
# hsapiens_paralog_orthology_type                                        description_4014
# hsapiens_paralog_perc_id                                                   perc_id_4015
# hsapiens_paralog_perc_id_r1                                             perc_id_4015_r1
# hsapiens_paralog_dn                                                             dn_4014
# hsapiens_paralog_ds                                                             ds_4014
# hsapiens_paralog_paralogy_confidence                            is_high_confidence_4014
# variation_name                                                                name_2025
# germ_line_variation_source                                                    name_2021
# source_description                                                     description_2021
# allele                                                               allele_string_2026
# validated                                                                 evidence_2025
# mapweight                                                               map_weight_2026
# minor_allele                                                          minor_allele_2025
# minor_allele_freq                                                minor_allele_freq_2025
# minor_allele_count                                              minor_allele_count_2025
# clinical_significance                                        clinical_significance_2025
# transcript_location                                                     cdna_start_2076
# snp_chromosome_strand                                            seq_region_strand_2026
# peptide_location                                                 translation_start_2076
# chromosome_start                                                  seq_region_start_2026
# chromosome_end                                                      seq_region_end_2026
# polyphen_prediction_2076                                       polyphen_prediction_2076
# polyphen_score_2076                                                 polyphen_score_2076
# sift_prediction_2076                                               sift_prediction_2076
# sift_score_2076                                                         sift_score_2076
# distance_to_transcript_2076                                 distance_to_transcript_2076
# cds_start_2076                                                           cds_start_2076
# cds_end_2076                                                               cds_end_2076
# peptide_shift                                                    pep_allele_string_2076
# synonymous_status                                                consequence_types_2076
# allele_string_2076                                                   allele_string_2076
# somatic_variation_name                                                        name_2025
# somatic_source_name                                                           name_2021
# somatic_source_description                                             description_2021
# somatic_allele                                                       allele_string_2026
# somatic_validated                                                         evidence_2025
# somatic_mapweight                                                       map_weight_2026
# somatic_minor_allele                                                  minor_allele_2025
# somatic_minor_allele_freq                                        minor_allele_freq_2025
# somatic_minor_allele_count                                      minor_allele_count_2025
# somatic_clinical_significance                                clinical_significance_2025
# somatic_transcript_location                                             cdna_start_2076
# somatic_snp_chromosome_strand                                    seq_region_strand_2026
# somatic_peptide_location                                         translation_start_2076
# somatic_chromosome_start                                          seq_region_start_2026
# somatic_chromosome_end                                              seq_region_end_2026
# mart_transcript_variation_som__dm_polyphen_pred...             polyphen_prediction_2076
# mart_transcript_variation_som__dm_polyphen_scor...                  polyphen_score_2076
# mart_transcript_variation_som__dm_sift_predicti...                 sift_prediction_2076
# mart_transcript_variation_som__dm_sift_score_2076                       sift_score_2076
# mart_transcript_variation_som__dm_distance_to_t...          distance_to_transcript_2076
# somatic_cds_start_2076                                                   cds_start_2076
# somatic_cds_end_2076                                                       cds_end_2076
# somatic_peptide_shift                                            pep_allele_string_2076
# somatic_synonymous_status                                        consequence_types_2076
# mart_transcript_variation_som__dm_allele_string...                   allele_string_2076
# transcript_exon_intron
# gene_exon_intron
# transcript_flank
# gene_flank
# coding_transcript_flank
# coding_gene_flank
# 5utr
# 3utr
# gene_exon
# cdna
# coding
# peptide
# upstream_flank
# downstream_flank

# %%
temp.T.loc["somatic_variation_name"][4]
# Out:
# 'hsapiens_gene_ensembl__mart_transcript_variation_som__dm'

# %%
bm.li

# %%
temp = pd.DataFrame()
for k,v in bm.attributes("hsapiens_gene_ensembl__mart_transcript_variation_som__dm").items():
    temp[k] = v
temp.T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-9d9f1f8125c2> in <module>
#       1 temp = pd.DataFrame()
# ----> 2 for k,v in bm.attributes("hsapiens_gene_ensembl__mart_transcript_variation_som__dm").items():
#       3     temp[k] = v
#       4 temp.T
#
# /opt/anaconda3/lib/python3.6/site-packages/bioservices/biomart.py in wrapper(*args, **kargs)
#      53             print("You must set the host (e.g. f.host='www.ensembl.org' ")
#      54             return
# ---> 55         return f(*args, **kargs)
#      56     return wrapper
#      57
#
# /opt/anaconda3/lib/python3.6/site-packages/bioservices/biomart.py in attributes(self, dataset)
#     310         #assert dataset in self.names
#     311         if dataset not in [x for k in self.valid_attributes.keys() for x in self.valid_attributes[k]]:
# --> 312             raise ValueError("provided dataset (%s) is not found. see valid_attributes" % dataset)
#     313         ret = self.http_get("?type=attributes&dataset=%s" %dataset, frmt='txt')
#     314
#
# ValueError: provided dataset (hsapiens_gene_ensembl__mart_transcript_variation_som__dm) is not found. see valid_attributes

# %%
bm.new_query()
bm.add_dataset_to_xml("hsapiens_gene_ensembl__mart_transcript_variation_som__dm")
# bm.attributes("ensembl_mart_sequence")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-91c76a610c5c> in <module>
#       1 bm.new_query()
# ----> 2 bm.add_dataset_to_xml("hsapiens_gene_ensembl__mart_transcript_variation_som__dm")
#       3 # bm.attributes("ensembl_mart_sequence")
#
# /opt/anaconda3/lib/python3.6/site-packages/bioservices/biomart.py in wrapper(*args, **kargs)
#      53             print("You must set the host (e.g. f.host='www.ensembl.org' ")
#      54             return
# ---> 55         return f(*args, **kargs)
#      56     return wrapper
#      57
#
# /opt/anaconda3/lib/python3.6/site-packages/bioservices/biomart.py in add_dataset_to_xml(self, dataset)
#     414     @require_host
#     415     def add_dataset_to_xml(self, dataset):
# --> 416         self.attributes(dataset)
#     417         #    raise BioServicesError("invalid dataset names provided. Check names attribute")
#     418         self._biomartQuery.add_dataset(dataset)
#
# /opt/anaconda3/lib/python3.6/site-packages/bioservices/biomart.py in wrapper(*args, **kargs)
#      53             print("You must set the host (e.g. f.host='www.ensembl.org' ")
#      54             return
# ---> 55         return f(*args, **kargs)
#      56     return wrapper
#      57
#
# /opt/anaconda3/lib/python3.6/site-packages/bioservices/biomart.py in attributes(self, dataset)
#     310         #assert dataset in self.names
#     311         if dataset not in [x for k in self.valid_attributes.keys() for x in self.valid_attributes[k]]:
# --> 312             raise ValueError("provided dataset (%s) is not found. see valid_attributes" % dataset)
#     313         ret = self.http_get("?type=attributes&dataset=%s" %dataset, frmt='txt')
#     314
#
# ValueError: provided dataset (hsapiens_gene_ensembl__mart_transcript_variation_som__dm) is not found. see valid_attributes

# %%
for at in attributes:
    bm.add_attribute_to_xml(at)
xml_query = bm.get_xml()

print("Querying {} from {}...".format(dataset, host))
results = bm.query(xml_query)
df = pd.read_csv(StringIO(results), header=None, names=attributes, sep="\t", index_col=None)
